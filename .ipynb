# %%
import requests

url = "https://api.sportradar.com/mlb/trial/v8/en/league/injuries.json"

headers = {
    "accept": "application/json",
    "x-api-key": "klO4acd3rXA5zSVNgG5QFnwntscHjSAeOOYIZIVJ"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"league":{"alias":"MLB","name":"Major League Baseball","id":"2fa448bc-fc17-4d3d-be03-e60e080fdc26"},"teams":[{"name":"Mets","market":"New York","abbr":"NYM","id":"f246a5e5-afdb-479c-9aaa-c68beeda7af6","players":[{"id":"04bbd2cb-cc77-41da-8550-e332c2da0cf1","status":"D60","position":"IF","primary_position":"3B","first_name":"Nicklaus","last_name":"Madrigal","preferred_name":"Nick","jersey_number":"11","full_name":"Nick Madrigal","injuries":[{"id":"d300fd2b-e0b1-477d-8582-f6d3fa3a5a0f","comment":"The New York Mets placed INF Nick Madrigal on the 60-day injured list. Madrigal will likely miss the entire season as he recovers from fractured left shoulder. ","desc":"Shoulder","status":"D60","start_date":"2025-02-24","update_date":"2025-02-24"}]},{"id":"6b4fd26d-3a3d-4aed-8f5a-36a91bd98861","status":"D60","position":"P","primary_position":"RP","first_name":"Dedniel","last_name":"Núñez","preferred_name":"Dedniel","jersey_number":"72","full_name":"Dedniel Núñez","injuries":[{"id":"df5ce335-6fdf-4633-9ecc-212e9278a4dc","comment":"The New York Mets transferred RHP Dedniel Núñez from the 15-day injured list to the 60-day injured list due to his right elbow.","desc":"Elbow","status":"D60","start_date":"2025-07-03","update_date":"2025-07-21"}]},{"id":"75147a4e-9c8c-4f58-8b38-a4d2847ff108","status":"D60","position":"P","primary_position":"SP","first_name":"Tylor","last_name":"Megill","preferred_name":"Tylor","jersey_number":"38","full_name":"Tylor Megill","injuries":[{"id":"2d7c24ec-84fe-4f93-9b58-b9a0a9a5831f","comment":"The New York Mets transferred RHP Tylor Megill from the 15-day injured list to the 60-day injured list due to elbow inflammation.","desc":"Elbow","status":"D60","start_date":"2025-06-15","update_date":"2025-07-08"}]},{"id":"7945584c-94fe-49e4-9d85-ad3ccd6b8617","status":"D60","position":"P","primary_position":"SP","first_name":"Christian","last_name":"Scott","preferred_name":"Christian","jersey_number":"45","full_name":"Christian Scott","injuries":[{"id":"51d08ac8-cf79-4df5-afd5-a6f100710b71","comment":"The New York Mets placed RHP Christian Scott on the 60-day injured list as he recovers from UCL sprain.","desc":"Elbow","status":"D60","start_date":"2025-02-26","update_date":"2025-02-26"}]},{"id":"a190b415-b572-4c98-b974-4f1b574f9d69","status":"D60","position":"P","primary_position":"SP","first_name":"Francelis","last_name":"Montas","preferred_name":"Frankie","jersey_number":"47","full_name":"Frankie Montas","injuries":[{"id":"20bd1b4b-1d77-4e58-8535-c17d643447d6","comment":"The New York Mets placed RHP Frankie Montas on the 60-day injured list.","desc":"Elbow","status":"D60","start_date":"2025-08-23","update_date":"2025-08-25"}]},{"id":"a37a751b-8a72-4bfc-8ac4-d980e97575e0","status":"D60","position":"P","primary_position":"RP","first_name":"Daniel","last_name":"Young","preferred_name":"Danny","jersey_number":"81","full_name":"Danny Young","injuries":[{"id":"ff7e4520-7eeb-43a7-9e39-641339c94ecd","comment":"The New York Mets transferred LHP Danny Young from the 15-day injured list to the 60-day injured list due to a left elbow sprain.","desc":"Elbow","status":"D60","start_date":"2025-04-27","update_date":"2025-05-04"}]},{"id":"e1cbb2df-986d-4fab-bf1e-7192c54bdae9","status":"D60","position":"P","primary_position":"RP","first_name":"Alex","last_name":"Minter","preferred_name":"A.J.","jersey_number":"33","full_name":"A.J. Minter","injuries":[{"id":"913a3153-1be8-4802-a4ea-6d82a40bf648","comment":"The New York Mets transferred LHP A.J. Minter from the 15-day injured list to the 60-day injured list due to a left lat strain.","desc":"Lat","status":"D60","start_date":"2025-04-26","update_date":"2025-05-01"}]},{"id":"f824c28f-19a6-468a-9e28-274c01534e5b","status":"D60","position":"P","primary_position":"RP","first_name":"Max","last_name":"Kranick","preferred_name":"Max","jersey_number":"32","full_name":"Max Kranick","injuries":[{"id":"63911ac2-3148-45ee-9624-b4e59bafc0a2","comment":"The New York Mets placed RHP Max Kranick on the  ...
